# %%
import os
import pandas as pd
import numpy as np
import torch
from torch.utils.data import DataLoader, TensorDataset
from sklearn.preprocessing import MinMaxScaler
from tqdm import tqdm

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
SELECTED_CSV_PATH = "/content/drive/MyDrive/LSTMAE_PROJECT/random_selected_stocks_sets_nodup.csv"

# 10컬럼 × 30row (selected_stocks1~10)
selected_df = pd.read_csv(SELECTED_CSV_PATH)
# 10개 세트 리스트로 변환
stock_sets = []
for col in selected_df.columns:
    stock_list = selected_df[col].dropna().tolist()
    stock_list = [str(s).strip() for s in stock_list]
    stock_sets.append(stock_list)

# %%
# ✅ LSTM-AE 정의
class LSTMAutoEncoder(torch.nn.Module):
    def __init__(self, input_dim, hidden_dim, latent_dim):
        super().__init__()
        self.encoder = torch.nn.LSTM(input_dim, hidden_dim, batch_first=True)
        self.latent = torch.nn.Linear(hidden_dim, latent_dim)
        self.decoder_input = torch.nn.Linear(latent_dim, hidden_dim)
        self.decoder = torch.nn.LSTM(hidden_dim, input_dim, batch_first=True)

    def forward(self, x):
        _, (h_n, _) = self.encoder(x)
        z = self.latent(h_n[-1])
        dec_input = self.decoder_input(z).unsqueeze(1).repeat(1, x.size(1), 1)
        out, _ = self.decoder(dec_input)
        return out

def create_sequences(data, window_size):
    return np.array([data[i:i+window_size] for i in range(len(data)-window_size)])

# ✅ 환경/하이퍼파라미터
features = ['종가', '대비', '등락률', '시가', '고가', '저가', '거래량', '거래대금', '시가총액', '상장주식수']
window_size = 30
batch_size = 32
n_epochs = 10
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
data_path = "/content/drive/MyDrive/LSTMAE_PROJECT/filtered_kospi_data_300.csv"
weight_save_dir = "/content/drive/MyDrive/LSTMAE_PROJECT/ensemble_weights"
thresh_save_dir = "/content/drive/MyDrive/LSTMAE_PROJECT/ensemble_thresholds"
os.makedirs(weight_save_dir, exist_ok=True)
os.makedirs(thresh_save_dir, exist_ok=True)

# ✅ 전체 데이터 로드
df_all = pd.read_csv(data_path)
df_all['날짜'] = pd.to_datetime(df_all['날짜'])

for set_idx, stock_list in enumerate(stock_sets, 1):
    weights_dict = {}
    thresholds_dict = {}

    for stock in tqdm(stock_list, desc=f"SET {set_idx}"):
        try:
            df = df_all[df_all['종목명'].str.strip() == stock.strip()].copy()
            if df.empty:
                print(f"[{stock}] 데이터 없음 - 스킵")
                continue

            df = df.sort_values('날짜').set_index('날짜')
            full_index = pd.date_range(df.index.min(), df.index.max(), freq='D')
            df = df.reindex(full_index)
            df[['종목코드', '종목명']] = df[['종목코드', '종목명']].fillna(method='ffill')
            df[features] = df[features].interpolate(method='linear').fillna(method='bfill').fillna(method='ffill')

            # 정규화
            scaler = MinMaxScaler()
            scaled = scaler.fit_transform(df[features].values)
            sequences = create_sequences(scaled, window_size)
            if len(sequences) < 10:
                print(f"[{stock}] 시퀀스 부족 - 스킵")
                continue

            tensor_data = torch.tensor(sequences, dtype=torch.float32)
            dataset = TensorDataset(tensor_data)
            loader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

            # 학습
            model = LSTMAutoEncoder(input_dim=len(features), hidden_dim=64, latent_dim=16).to(device)
            criterion = torch.nn.MSELoss()
            optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
            model.train()
            for epoch in range(n_epochs):
                for batch in loader:
                    x = batch[0].to(device)
                    output = model(x)
                    loss = criterion(output, x)
                    optimizer.zero_grad()
                    loss.backward()
                    optimizer.step()

            # 가중치 저장 (딕셔너리)
            weights_dict[stock] = model.state_dict()

            # 임계치 계산 (validation/recon error 기준)
            model.eval()
            errors = []
            with torch.no_grad():
                for batch in DataLoader(dataset, batch_size=64, shuffle=False):
                    x = batch[0].to(device)
                    output = model(x)
                    loss = torch.mean((x - output) ** 2, dim=[1, 2])
                    errors.extend(loss.cpu().numpy())
            errors = np.array(errors)
            k = 3  # threshold factor
            threshold = np.mean(errors) + k * np.std(errors)
            thresholds_dict[stock] = float(threshold)

        except Exception as e:
            print(f"[{stock}] 처리 실패: {e}")

    # SET별로 묶어서 저장
    torch.save(weights_dict, f"{weight_save_dir}/ensemble_weights_set{set_idx}.pt")
    thresh_df = pd.DataFrame(list(thresholds_dict.items()), columns=['종목명', '임계값'])
    thresh_df.to_csv(f"{thresh_save_dir}/ensemble_thresholds_set{set_idx}.csv", index=False, encoding='utf-8-sig')

    print(f"\n[SET {set_idx}] 30개 종목 모델 및 임계값 저장 완료.\n")
# Out:
# /tmp/ipython-input-6-3274379468.py:33: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_all = pd.read_csv(data_path)
# SET 1:   0%|          | 0/30 [00:00<?, ?it/s]/tmp/ipython-input-6-3274379468.py:50: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[['종목코드', '종목명']] = df[['종목코드', '종목명']].fillna(method='ffill')
# /tmp/ipython-input-6-3274379468.py:51: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[features] = df[features].interpolate(method='linear').fillna(method='bfill').fillna(method='ffill')
# SET 1:   3%|▎         | 1/30 [00:13<06:21, 13.16s/it]/tmp/ipython-input-6-3274379468.py:50: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[['종목코드', '종목명']] = df[['종목코드', '종목명']].fillna(method='ffill')
# /tmp/ipython-input-6-3274379468.py:50: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[['종목코드', '종목명']] = df[['종목코드', '종목명']].fillna(method='ffill')
# /tmp/ipython-input-6-3274379468.py:51: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[features] = df[features].interpolate(method='linear').fillna(method='bfill').fillna(method='ffill')
# SET 1:   7%|▋         | 2/30 [00:16<03:24,  7.31s/it]/tmp/ipython-input-6-3274379468.py:50: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[['종목코드', '종목명']] = df[['종목코드', '종목명']].fillna(method='ffill')
# /tmp/ipython-input-6-3274379468.py:50: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[['종목코드', '종목명']] = df[['종목코드', '종목명']].fillna(method='ffill')
# /tmp/ipython-input-6-3274379468.py:51: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[features] = df[features].interpolate(method='linear').fillna(method='bfill').fillna(method='ffill')
# SET 1:  10%|█         | 3/30 [00:17<01:58,  4.38s/it]/tmp/ipython-input-6-3274379468.py:50: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[['종목코드', '종목명']] = df[['종목코드', '종목명']].fillna(method='ffill')
# /tmp/ipython-input-6-3274379468.py:50: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[['종목코드', '종목명']] = df[['종목코드', '종목명']].fillna(method='ffill')
# /tmp/ipython-input-6-3274379468.py:51: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[features] = df[features].interpolate(method='linear').fillna(method='bfill').fillna(method='ffill')
# SET 1:  13%|█▎        | 4/30 [00:19<01:34,  3.62s/it]/tmp/ipython-input-6-3274379468.py:50: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[['종목코드', '종목명']] = df[['종목코드', '종목명']].fillna(method='ffill')
# /tmp/ipython-input-6-3274379468.py:51: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[features] = df[features].interpolate(method='linear').fillna(method='bfill').fillna(method='ffill')
# SET 1:  17%|█▋        | 5/30 [00:34<03:13,  7.73s/it]/tmp/ipython-input-6-3274379468.py:50: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[['종목코드', '종목명']] = df[['종목코드', '종목명']].fillna(method='ffill')
# /tmp/ipython-input-6-3274379468.py:50: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[['종목코드', '종목명']] = df[['종목코드', '종목명']].fillna(method='ffill')
# /tmp/ipython-input-6-3274379468.py:51: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[features] = df[features].interpolate(method='linear').fillna(method='bfill').fillna(method='ffill')
# SET 1:  20%|██        | 6/30 [00:39<02:37,  6.58s/it]/tmp/ipython-input-6-3274379468.py:50: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[['종목코드', '종목명']] = df[['종목코드', '종목명']].fillna(method='ffill')
# /tmp/ipython-input-6-3274379468.py:50: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[['종목코드', '종목명']] = df[['종목코드', '종목명']].fillna(method='ffill')
# /tmp/ipython-input-6-3274379468.py:51: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[features] = df[features].interpolate(method='linear').fillna(method='bfill').fillna(method='ffill')
# SET 1:  23%|██▎       | 7/30 [00:55<03:46,  9.83s/it]/tmp/ipython-input-6-3274379468.py:50: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[['종목코드', '종목명']] = df[['종목코드', '종목명']].fillna(method='ffill')
# /tmp/ipython-input-6-3274379468.py:51: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[features] = df[features].interpolate(method='linear').fillna(method='bfill').fillna(method='ffill')
# SET 1:  27%|██▋       | 8/30 [00:57<02:43,  7.45s/it]/tmp/ipython-input-6-3274379468.py:50: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[['종목코드', '종목명']] = df[['종목코드', '종목명']].fillna(method='ffill')
# /tmp/ipython-input-6-3274379468.py:50: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[['종목코드', '종목명']] = df[['종목코드', '종목명']].fillna(method='ffill')
# /tmp/ipython-input-6-3274379468.py:51: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[features] = df[features].interpolate(method='linear').fillna(method='bfill').fillna(method='ffill')
# SET 1:  30%|███       | 9/30 [01:02<02:17,  6.57s/it]/tmp/ipython-input-6-3274379468.py:50: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[['종목코드', '종목명']] = df[['종목코드', '종목명']].fillna(method='ffill')
# /tmp/ipython-input-6-3274379468.py:50: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[['종목코드', '종목명']] = df[['종목코드', '종목명']].fillna(method='ffill')
# /tmp/ipython-input-6-3274379468.py:51: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[features] = df[features].interpolate(method='linear').fillna(method='bfill').fillna(method='ffill')
# SET 1:  33%|███▎      | 10/30 [01:13<02:39,  7.97s/it]/tmp/ipython-input-6-3274379468.py:50: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[['종목코드', '종목명']] = df[['종목코드', '종목명']].fillna(method='ffill')
# /tmp/ipython-input-6-3274379468.py:50: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[['종목코드', '종목명']] = df[['종목코드', '종목명']].fillna(method='ffill')
# /tmp/ipython-input-6-3274379468.py:51: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[features] = df[features].interpolate(method='linear').fillna(method='bfill').fillna(method='ffill')
# SET 1:  37%|███▋      | 11/30 [01:20<02:24,  7.60s/it]/tmp/ipython-input-6-3274379468.py:50: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[['종목코드', '종목명']] = df[['종목코드', '종목명']].fillna(method='ffill')
# /tmp/ipython-input-6-3274379468.py:51: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[features] = df[features].interpolate(method='linear').fillna(method='bfill').fillna(method='ffill')
# SET 1:  40%|████      | 12/30 [01:26<02:10,  7.23s/it]/tmp/ipython-input-6-3274379468.py:50: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[['종목코드', '종목명']] = df[['종목코드', '종목명']].fillna(method='ffill')
# /tmp/ipython-input-6-3274379468.py:50: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[['종목코드', '종목명']] = df[['종목코드', '종목명']].fillna(method='ffill')
# /tmp/ipython-input-6-3274379468.py:51: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[features] = df[features].interpolate(method='linear').fillna(method='bfill').fillna(method='ffill')
# SET 1:  43%|████▎     | 13/30 [01:28<01:36,  5.68s/it]/tmp/ipython-input-6-3274379468.py:50: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[['종목코드', '종목명']] = df[['종목코드', '종목명']].fillna(method='ffill')
# /tmp/ipython-input-6-3274379468.py:51: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[features] = df[features].interpolate(method='linear').fillna(method='bfill').fillna(method='ffill')
# SET 1:  47%|████▋     | 14/30 [01:30<01:08,  4.31s/it]/tmp/ipython-input-6-3274379468.py:50: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[['종목코드', '종목명']] = df[['종목코드', '종목명']].fillna(method='ffill')
# /tmp/ipython-input-6-3274379468.py:50: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[['종목코드', '종목명']] = df[['종목코드', '종목명']].fillna(method='ffill')
# /tmp/ipython-input-6-3274379468.py:51: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[features] = df[features].interpolate(method='linear').fillna(method='bfill').fillna(method='ffill')
# SET 1:  50%|█████     | 15/30 [01:33<01:01,  4.12s/it]/tmp/ipython-input-6-3274379468.py:50: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[['종목코드', '종목명']] = df[['종목코드', '종목명']].fillna(method='ffill')
# /tmp/ipython-input-6-3274379468.py:51: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[features] = df[features].interpolate(method='linear').fillna(method='bfill').fillna(method='ffill')
# SET 1:  53%|█████▎    | 16/30 [01:36<00:50,  3.64s/it]/tmp/ipython-input-6-3274379468.py:50: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[['종목코드', '종목명']] = df[['종목코드', '종목명']].fillna(method='ffill')
# /tmp/ipython-input-6-3274379468.py:50: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[['종목코드', '종목명']] = df[['종목코드', '종목명']].fillna(method='ffill')
# /tmp/ipython-input-6-3274379468.py:51: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[features] = df[features].interpolate(method='linear').fillna(method='bfill').fillna(method='ffill')
# SET 1:  57%|█████▋    | 17/30 [01:42<00:57,  4.46s/it]/tmp/ipython-input-6-3274379468.py:50: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[['종목코드', '종목명']] = df[['종목코드', '종목명']].fillna(method='ffill')
# /tmp/ipython-input-6-3274379468.py:50: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[['종목코드', '종목명']] = df[['종목코드', '종목명']].fillna(method='ffill')
# /tmp/ipython-input-6-3274379468.py:51: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[features] = df[features].interpolate(method='linear').fillna(method='bfill').fillna(method='ffill')
# SET 1:  60%|██████    | 18/30 [02:06<02:01, 10.15s/it]/tmp/ipython-input-6-3274379468.py:50: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[['종목코드', '종목명']] = df[['종목코드', '종목명']].fillna(method='ffill')
# /tmp/ipython-input-6-3274379468.py:51: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[features] = df[features].interpolate(method='linear').fillna(method='bfill').fillna(method='ffill')
# SET 1:  63%|██████▎   | 19/30 [02:20<02:04, 11.28s/it]/tmp/ipython-input-6-3274379468.py:50: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[['종목코드', '종목명']] = df[['종목코드', '종목명']].fillna(method='ffill')
# /tmp/ipython-input-6-3274379468.py:51: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[features] = df[features].interpolate(method='linear').fillna(method='bfill').fillna(method='ffill')
# SET 1:  67%|██████▋   | 20/30 [02:37<02:10, 13.06s/it]/tmp/ipython-input-6-3274379468.py:50: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[['종목코드', '종목명']] = df[['종목코드', '종목명']].fillna(method='ffill')
# /tmp/ipython-input-6-3274379468.py:51: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[features] = df[features].interpolate(method='linear').fillna(method='bfill').fillna(method='ffill')
# SET 1:  70%|███████   | 21/30 [02:52<02:03, 13.67s/it]/tmp/ipython-input-6-3274379468.py:50: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[['종목코드', '종목명']] = df[['종목코드', '종목명']].fillna(method='ffill')
# /tmp/ipython-input-6-3274379468.py:50: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[['종목코드', '종목명']] = df[['종목코드', '종목명']].fillna(method='ffill')
# /tmp/ipython-input-6-3274379468.py:51: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[features] = df[features].interpolate(method='linear').fillna(method='bfill').fillna(method='ffill')
# SET 1:  73%|███████▎  | 22/30 [03:05<01:49, 13.66s/it]/tmp/ipython-input-6-3274379468.py:50: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[['종목코드', '종목명']] = df[['종목코드', '종목명']].fillna(method='ffill')
# /tmp/ipython-input-6-3274379468.py:51: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[features] = df[features].interpolate(method='linear').fillna(method='bfill').fillna(method='ffill')
# SET 1:  77%|███████▋  | 23/30 [03:09<01:13, 10.51s/it]/tmp/ipython-input-6-3274379468.py:50: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[['종목코드', '종목명']] = df[['종목코드', '종목명']].fillna(method='ffill')
# /tmp/ipython-input-6-3274379468.py:51: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[features] = df[features].interpolate(method='linear').fillna(method='bfill').fillna(method='ffill')
# SET 1:  80%|████████  | 24/30 [03:32<01:25, 14.31s/it]/tmp/ipython-input-6-3274379468.py:50: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[['종목코드', '종목명']] = df[['종목코드', '종목명']].fillna(method='ffill')
# /tmp/ipython-input-6-3274379468.py:50: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[['종목코드', '종목명']] = df[['종목코드', '종목명']].fillna(method='ffill')
# /tmp/ipython-input-6-3274379468.py:51: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[features] = df[features].interpolate(method='linear').fillna(method='bfill').fillna(method='ffill')
# SET 1:  83%|████████▎ | 25/30 [03:36<00:56, 11.24s/it]/tmp/ipython-input-6-3274379468.py:50: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[['종목코드', '종목명']] = df[['종목코드', '종목명']].fillna(method='ffill')
# /tmp/ipython-input-6-3274379468.py:50: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[['종목코드', '종목명']] = df[['종목코드', '종목명']].fillna(method='ffill')
# /tmp/ipython-input-6-3274379468.py:51: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[features] = df[features].interpolate(method='linear').fillna(method='bfill').fillna(method='ffill')
# SET 1:  87%|████████▋ | 26/30 [03:42<00:38,  9.73s/it]/tmp/ipython-input-6-3274379468.py:50: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[['종목코드', '종목명']] = df[['종목코드', '종목명']].fillna(method='ffill')
# /tmp/ipython-input-6-3274379468.py:50: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[['종목코드', '종목명']] = df[['종목코드', '종목명']].fillna(method='ffill')
# /tmp/ipython-input-6-3274379468.py:51: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[features] = df[features].interpolate(method='linear').fillna(method='bfill').fillna(method='ffill')
# SET 1:  90%|█████████ | 27/30 [04:00<00:36, 12.22s/it]/tmp/ipython-input-6-3274379468.py:50: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[['종목코드', '종목명']] = df[['종목코드', '종목명']].fillna(method='ffill')
# /tmp/ipython-input-6-3274379468.py:50: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[['종목코드', '종목명']] = df[['종목코드', '종목명']].fillna(method='ffill')
# /tmp/ipython-input-6-3274379468.py:51: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[features] = df[features].interpolate(method='linear').fillna(method='bfill').fillna(method='ffill')
# SET 1:  93%|█████████▎| 28/30 [04:07<00:20, 10.49s/it]/tmp/ipython-input-6-3274379468.py:50: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[['종목코드', '종목명']] = df[['종목코드', '종목명']].fillna(method='ffill')
# /tmp/ipython-input-6-3274379468.py:50: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[['종목코드', '종목명']] = df[['종목코드', '종목명']].fillna(method='ffill')
# /tmp/ipython-input-6-3274379468.py:51: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[features] = df[features].interpolate(method='linear').fillna(method='bfill').fillna(method='ffill')
# SET 1:  97%|█████████▋| 29/30 [04:24<00:12, 12.58s/it]/tmp/ipython-input-6-3274379468.py:50: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[['종목코드', '종목명']] = df[['종목코드', '종목명']].fillna(method='ffill')
# /tmp/ipython-input-6-3274379468.py:50: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[['종목코드', '종목명']] = df[['종목코드', '종목명']].fillna(method='ffill')
# /tmp/ipython-input-6-3274379468.py:51: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[features] = df[features].interpolate(method='linear').fillna(method='bfill').fillna(method='ffill')
# SET 1: 100%|██████████| 30/30 [04:30<00:00,  9.02s/it]
# [SET 1] 30개 종목 모델 및 임계값 저장 완료.
# SET 2:   0%|          | 0/30 [00:00<?, ?it/s]/tmp/ipython-input-6-3274379468.py:50: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[['종목코드', '종목명']] = df[['종목코드', '종목명']].fillna(method='ffill')
# /tmp/ipython-input-6-3274379468.py:50: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[['종목코드', '종목명']] = df[['종목코드', '종목명']].fillna(method='ffill')
# /tmp/ipython-input-6-3274379468.py:51: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[features] = df[features].interpolate(method='linear').fillna(method='bfill').fillna(method='ffill')
# SET 2:   3%|▎         | 1/30 [00:28<13:34, 28.09s/it]/tmp/ipython-input-6-3274379468.py:50: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[['종목코드', '종목명']] = df[['종목코드', '종목명']].fillna(method='ffill')
# /tmp/ipython-input-6-3274379468.py:50: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[['종목코드', '종목명']] = df[['종목코드', '종목명']].fillna(method='ffill')
# /tmp/ipython-input-6-3274379468.py:51: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[features] = df[features].interpolate(method='linear').fillna(method='bfill').fillna(method='ffill')
# SET 2:   7%|▋         | 2/30 [00:55<12:56, 27.72s/it]/tmp/ipython-input-6-3274379468.py:50: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[['종목코드', '종목명']] = df[['종목코드', '종목명']].fillna(method='ffill')
# /tmp/ipython-input-6-3274379468.py:50: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[['종목코드', '종목명']] = df[['종목코드', '종목명']].fillna(method='ffill')
# /tmp/ipython-input-6-3274379468.py:51: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[features] = df[features].interpolate(method='linear').fillna(method='bfill').fillna(method='ffill')
# SET 2:  10%|█         | 3/30 [01:04<08:42, 19.37s/it]/tmp/ipython-input-6-3274379468.py:50: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[['종목코드', '종목명']] = df[['종목코드', '종목명']].fillna(method='ffill')
# /tmp/ipython-input-6-3274379468.py:51: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[features] = df[features].interpolate(method='linear').fillna(method='bfill').fillna(method='ffill')
# SET 2: